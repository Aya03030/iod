# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.1.2
# # *Exploring Data*

# %% [markdown]
# ## Part 1: Continuous and Categorical Data

# %% [markdown]
# When we explore a dataset we usually produce textual and graphical output together, starting with a high-level overview of the data and gradually drilling down into the individual features and relationships between them.

# %% [markdown]
# Our most important libraries for this task are:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# Override default figure sizing:
pylab.rcParams['figure.figsize'] = (10, 6)
sns.set(color_codes = True)

# %% [markdown]
# ## Data Profiling
#
# We actually start profiling the data when we first load it and check for input errors, as in the last lab. Once we have a DataFrame we can work with, however, things start getting more interesting.

# %% [markdown]
# **Load the file "bikeshare.csv" into a DataFrame named `bikes`, and check that it was loaded properly:**

# %%
#ANSWER:

bikes = pd.read_csv('/Users/ayano/Desktop/Data Science & AI/csv/bikeshare.csv', index_col = 0)
bikes.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# We may want our program to capture particular features of the dataset into variables, but if we just want to get a feel for the data it is easier to use a higher-level Pandas method like `describe()`:
#
# **Use `describe` to get the description of datasets.**

# %%
#ANSWER:

bikes.describe().T
# Out:
#               count        mean         std   min      25%       50%  \
# season      17379.0    2.501640    1.106918  1.00   2.0000    3.0000
# yr          17379.0    0.502561    0.500008  0.00   0.0000    1.0000
# mnth        17379.0    6.537775    3.438776  1.00   4.0000    7.0000
# hr          17379.0   11.546752    6.914405  0.00   6.0000   12.0000
# holiday     17379.0    0.028770    0.167165  0.00   0.0000    0.0000
# weekday     17379.0    3.003683    2.005771  0.00   1.0000    3.0000
# workingday  17379.0    0.682721    0.465431  0.00   0.0000    1.0000
# weathersit  17379.0    1.425283    0.639357  1.00   1.0000    1.0000
# temp        17379.0    0.496987    0.192556  0.02   0.3400    0.5000
# atemp       17379.0    0.475775    0.171850  0.00   0.3333    0.4848
# hum         17379.0    0.627229    0.192930  0.00   0.4800    0.6300
# windspeed   17379.0    0.190098    0.122340  0.00   0.1045    0.1940
# casual      17379.0   35.676218   49.305030  0.00   4.0000   17.0000
# registered  17379.0  153.786869  151.357286  0.00  34.0000  115.0000
# cnt         17379.0  189.463088  181.387599  1.00  40.0000  142.0000
#
#                  75%       max
# season        3.0000    4.0000
# yr            1.0000    1.0000
# mnth         10.0000   12.0000
# hr           18.0000   23.0000
# holiday       0.0000    1.0000
# weekday       5.0000    6.0000
# workingday    1.0000    1.0000
# weathersit    2.0000    4.0000
# temp          0.6600    1.0000
# atemp         0.6212    1.0000
# hum           0.7800    1.0000
# windspeed     0.2537    0.8507
# casual       48.0000  367.0000
# registered  220.0000  886.0000
# cnt         281.0000  977.0000

# %%
bikes.shape
# Out:
# (17379, 16)

# %%
bikes.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# ### Continuous Data

# %% [markdown]
# We may have to do a lot of work before we can produce presentable graphics, but we can start creating simple visualisations as soon as we have a DataFrame.
#
# We usually start charting variables one-by-one (although when several have the same range it may be preferable to overlay them, using a different colour or symbol for each).

# %% [markdown]
# **Use the `scatter` method of Pandas to create a scatter plot of `windspeed`, `temp`:**

# %%
#ANSWER

# 散布図を作成
bikes.plot.scatter('temp', 'windspeed', c='blue', marker='o', label='')

#グラフにタイトルと軸ラベルを追加
plt.title('Windspeed vs. Temperature Scatter Plot')
plt.xlabel('Windspeed')
plt.ylabel('Temperature')

#グラフを表示
plt.show()

# %% [markdown]
# **The `scatter` method has various parameters for controlling the appearance of the chart. Experiment with `s` , `linewidths`, and `alpha` below:**

# %%
#ANSWER

# 散布図を作成
bikes.plot.scatter('temp' ,'windspeed', s=20, linewidths=1, alpha=0.5)

#グラフにタイトルと軸ラベルを追加
plt.title('Windspeed vs. Temperature Scatter Plot')
plt.xlabel('Windspeed')
plt.ylabel('Temperature')

#グラフを表示
plt.show()

# %% [markdown]
# The scatterplot shows us the raw data. Our next step is usually to see how it is distributed, which is what the histogram is for:
#
# > A histogram is used for continuous data, where the bins represent ranges of data, while a bar chart is a plot of categorical variables. <sup>[1](#histfootnote)</sup>
#
# - **Identify continuous varaibles**
# - **Create histogram for those variables**

# %%
#ANSWER

bikes['atemp'].hist(figsize = (20, 10))
# Out:
# <Axes: >

# %% [markdown]
# What do the horizontal and vertical axes represent?

# %% [markdown]
# #### ANSWER:
#     horiz = magnitude of `atemp`, apparently normalised to [0, 1], discretised into bins of width 0.1;
#     vertical = counts of samples in each bin.

# %% [markdown]
# *NOTE: Samples in a given bin are greater than the axis value of its left side and less than or equal to the axis value of its right side. (The left-most bin is an exception: it represents greater than or equal to.)*

# %% [markdown]
# The box-and-whisker plot provides a compact view of the major percentiles of the distribution:
#
# **Make a box and whisker plot for the column ``atemp``.**
#
# > The box extends from the lower to
# upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data.  Flier points are those past the end of the whiskers.

# %%
#ANSWER

#ボックスプロットを作成
plt.boxplot(bikes['atemp']);

# %% [markdown]
# This kind of plot really shines when we want to show several distributions at once (as long as they have compatible ranges).
#
# **Plot `atemp` and `windspeed` together. Change labels accordingly.**

# %%
#ANSWER

#atempとwindspeedの箱ひげ図を作成し、ラベルを追加
plt.boxplot((bikes['atemp'], bikes['windspeed']), labels = ['atemp', 'windspeed']);

# %% [markdown]
# ### Classified Data
#
# Samples may represent different classes according to one or more categorical variables. Sometimes our goal is to discover these classes, or to train a classification model from samples that have been manually classified.

# %% [markdown]
# Here, the famous "Iris" dataset gets loaded from the UCI repository:

# %%
import urllib

# get Iris dataset from UCI Machine Learning Repository:
url = "http://goo.gl/HppjFh"
raw_data = urllib.request.urlopen(url)

# load the CSV file:
iris_data = pd.read_csv(raw_data, delimiter = ",",
                        names = ('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))

# %% [markdown]
# Note that the column names were overridden by the `names` argument of the Pandas `read.csv` method. This requires prior knowledge of the dataset, which we would normally get from a data dictionary (although sometimes we just have to figure it out for ourselves).

# %% [markdown]
# **Print the first few rows of this DataFrame:**

# %%
#ANSWER

iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# In this dataset, `species` has several possible values (representing the classes of the samples).
#
# **Find out distinct number of `species` and number of sample for each `species` in this dataset.**

# %%
#ANSWER

iris_data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# We often need to capture the number of classes in code. We can do this with a variation on the above. Try this below:

# %%
#ANSWER

len(iris_data['species'].value_counts())
# Out:
# 3

# %% [markdown]
# We often need to calculate aggregate values within subgroups of the dataset. The Pandas DataFrame method for this is `groupby`.
#
# **Apply the `groupby` method to get `mean` of `sepal_length` and `sepal_width` for the above dataset.**

# %%
#ANSWER

_group_by = ['species']

_agg = {'sepal_length' : 'mean',
        'sepal_width' : 'mean'}

iris_data_groupby = iris_data.groupby(by = ['species']).agg({'sepal_length' : 'mean', 'sepal_width' : 'mean'})

# %%
iris_data_groupby.head()
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             5.006        3.418
# Iris-versicolor         5.936        2.770
# Iris-virginica          6.588        2.974

# %% [markdown]
# The Pandas `plot` method provides a quick way to produce a scatter plot.
#
# **Draw a Scatterplot showing sepal width and length using the Pandas `plot` method.**

# %%
#ANSWER

#散布図を作成し、軸ラベルを追加
iris_data.plot(kind = 'scatter' , x = 'sepal_width', y = 'sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# **Draw a Barplot showing sepal width and length using the Pandas plot method.**

# %%
#ANSWER

#棒グラフを作成
iris_data_groupby.plot(kind = 'bar')
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# Draw a Scatterplot showing sepal width and length using the Pandas plot method.
#
# **[BONUS] Set `title`, `xlabel`, `ylabel` to the plot**

# %%
#ANSWER

#散布図を作成
plt.scatter(iris_data['sepal_width'], iris_data['sepal_length'], s=10, linewidths=3, alpha=0.5)

#タイトルと軸ラベルを追加
plt.title('Scatter Plot of Sepal Width vs. Sepal Length')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')

#図を表示
plt.show()

# %%
#散布図を作成
iris_data.plot(kind = 'scatter' , x = 'sepal_width', y = 'sepal_length', s=10, linewidths=3, alpha=0.5)

#タイトルと軸ラベルを追加
plt.title('Scatter Plot of Sepal Width vs. Sepal Length')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')

#図を表示
plt.show()

# %% [markdown]
# In this dataset we have also `petal_width`, `petal_length`.
#
# **Try to draw Scatterplot using these variables.**

# %%
#ANSWER

#散布図を作成
iris_data.plot(kind = 'scatter' , x = 'petal_width', y = 'petal_length', s=50, linewidths=1, alpha=0.5)

#タイトルと軸ラベルを追加
plt.title('Scatter Plot of Petal Width vs. Petal Length')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')

#図を表示
plt.show()

# %% [markdown]
# In this case, we already have different species, so we can colour the points accordingly. This is easy to do using the Seaborn library. Try using `lmplot` of seaborn library and use the parameter `hue` and `fit_reg = False`.
#
# **Draw a Scatterplot showing sepal width and length.**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:

sns.lmplot(x= 'sepal_width', y = 'sepal_length', hue = 'species', data = iris_data, fit_reg = False)

# %% [markdown]
# **[BONUS] Draw a Scatterplot showing sepal width and length. Without using seaborn.**

# %%
# ANSWER

color_labels =iris_data['species'].unique()
reg_values = sns.color_palette('Set2', 8)
color_map =dict(zip(color_labels, reg_values))
plt.scatter(iris_data['sepal_width'], iris_data['sepal_length'], c= iris_data['species'].map(color_map))

# %% [markdown]
# To find out why this function is called `lmplot`, try it again with `fit_reg` = True:
#
# **Draw a Scatterplot showing sepal width and length:**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:

sns.lmplot(x='sepal_length', y='sepal_width', hue='species', data = iris_data)

# %% [markdown]
# The Seaborn `jointplot` function charts a correlation along with both distributions:
#
# **Draw a jointplot showing sepal width and length:**

# %%
# ANSWER

sns.jointplot( x= 'sepal_width', y= 'sepal_length', data = iris_data)

# %% [markdown]
# When we want to see all the correlations at once, we can use `pairplot`:
#
# **Draw a `pairplot` of the dataset:**

# %%
# ANSWER

sns.pairplot(iris_data)

# %% [markdown]
# And, if the classes are known, we can apply colour using the `hue` parameter. Try this below:

# %%
# ANSWER

sns.pairplot(iris_data, hue = 'species')

# %% [markdown]
# Note that this gave us class-based distributions instead of an overall histogram, as well.

# %% [markdown]
# When we want to see numerical values of the correlations, the Pandas `corr` method provides a table of pair-wise correlations between the features in the DataFrame:

# %%
# ANSWER

iris_data.corr()
# Out:
# /var/folders/0z/jn67d04d61x09rscj406r8zr0000gn/T/ipykernel_58339/426526115.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### High-Level Data Profiling Libraries

# %% [markdown]
# We need to master the basic data profiling functions because we will by using them frequently, for exploring data and answering ad hoc questions. In a production solution, we may need to incorporate specific data profiling code into our script so that we can automate data cleaning. However, when we just want to examine the data interactively before we start modelling, it is easier to use a high-level library like the following:
#
# > pip install sweetviz

# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in /Users/ayano/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (1.24.3)
# Requirement already satisfied: matplotlib>=3.1.3 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (1.10.1)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.2.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from sweetviz) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)

# %%
# ANSWER
import pandas as pd
import sweetviz as sv
df = pd.read_csv("/Users/ayano/Desktop/Data Science & AI/csv/Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong               GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775000, 6.083330)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333    (56.183330, 10.233330)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000  (54.216670, -113.000000)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000   (16.883330, -99.900000)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000  (-33.166670, -64.950000)
# 5  01/01/1919 12:00:00 AM  32.10000   71.80000    (32.100000, 71.800000)
# 6  01/01/1949 12:00:00 AM  44.83333   95.16667    (44.833330, 95.166670)
# 7  01/01/1814 12:00:00 AM  44.21667    0.61667     (44.216670, 0.616670)
# 8  01/01/1930 12:00:00 AM -31.60000  -65.23333  (-31.600000, -65.233330)
# 9  01/01/1920 12:00:00 AM -30.86667  -64.55000  (-30.866670, -64.550000)

# %% [markdown]
# Use `analyze` and `show_html` of `sweetviz` to get an overview of the dataset.

# %%
# ANSWER

my_report =sv.analyze(df)
my_report.show_html()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Part 2: Time Series and Geospatial Data

# %% [markdown]
# ## Time Series
#
# A time series is basically a series or a data frame with a time-based index column. Working with time series introduces a lot of challenges and possibilities, but most tasks are catered for by the standard libraries in Python.

# %% [markdown]
# Here is a history of air passenger counts by month, loaded into an ordinary DataFrame:

# %%
airpass = pd.read_csv('/Users/ayano/Desktop/Data Science & AI/csv/AirPassengers.csv')
airpass.head()
# Out:
#   TravelDate  Passengers
# 0   1/1/1949         112
# 1   2/1/1949         118
# 2   3/1/1949         132
# 3   4/1/1949         129
# 4   5/1/1949         121

# %%
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Before going any further, the `TravelDate` column needs to be converted to the `datetime` type.

# %%
# ANSWER

airpass['TravelDate'] = pd.to_datetime(airpass['TravelDate'], format = '%d/%m/%Y')
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %% [markdown]
# Set `TravelDate` as index

# %%
# ANSWER

airpass.set_index('TravelDate', inplace=True)

# %% [markdown]
# Now, Pandas knows that the first column of this DataFrame is a datetime index, so it only shows one column of data:
#
# Use `head` to check.

# %%
# ANSWER

airpass.head()
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-01-02         118
# 1949-01-03         132
# 1949-01-04         129
# 1949-01-05         121

# %% [markdown]
# Here's how to see the values of the index:

# %%
airpass.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-01-02', '1949-01-03', '1949-01-04',
#                '1949-01-05', '1949-01-06', '1949-01-07', '1949-01-08',
#                '1949-01-09', '1949-01-10',
#                ...
#                '1960-01-03', '1960-01-04', '1960-01-05', '1960-01-06',
#                '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#                '1960-01-11', '1960-01-12'],
#               dtype='datetime64[ns]', name='TravelDate', length=144, freq=None)

# %% [markdown]
# If we had multiple data columns but we only wanted to work with a time series of one of them, we could pull that column into a 1D time series:

# %%
ts = airpass['Passengers']

# %% [markdown]
# We use the datetime index exactly like a row number index:

# %%
print(ts['1949-01-01'])
# Out:
# 112

# %% [markdown]
# Or, we can refer to the row by its datetime equivalent:

# %%
from datetime import datetime
print(ts[datetime(1949,1,1)])
# Out:
# 112

# %% [markdown]
# Happily, Pandas makes it easy to slice data at a courser grain. We can refer to a whole year of data by omitting the month and day form the index:

# %%
print(ts['1949'])
# Out:
# TravelDate
# 1949-01-01    112
# 1949-01-02    118
# 1949-01-03    132
# 1949-01-04    129
# 1949-01-05    121
# 1949-01-06    135
# 1949-01-07    148
# 1949-01-08    148
# 1949-01-09    136
# 1949-01-10    119
# 1949-01-11    104
# 1949-01-12    118
# Name: Passengers, dtype: int64

# %% [markdown]
# The most basic way to plot a time series is to let Pandas apply the default:

# %%
ts.plot();

# %% [markdown]
# ## Geospatial Data
#
# Geospatial data is map-based (although what constitutes a "map" can go beyond the familiar). Ultimately, geographic data  occurs either in bitmap (raster) form or vector (resizeable polygons). It is not unusual for the two kinds of data to be used together.
#
# Because borders are often complex, following river courses, mountain ranges, and so on, the files that describe their geometries can be large. To reduce file sizes and image rendering times, we prefer to work with polygons that are no more detailed than the maximum resolution we need for our task. For this reason, geospatial files are often available at several different resolutions.

# %% [markdown]
# There are several popular options for working with maps in Python. We will use folium for its breadth and its use of open-source data.

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /Users/ayano/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/ayano/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/ayano/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayano/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
# Read SF Incidents data
crime_csv = '/Users/ayano/Desktop/Data Science & AI/csv/SFPD_Incidents-Current_Year_2015.csv'

crimedate = pd.read_csv(crime_csv)

# %%
crimedate.head()
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1   150827213       ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4   150827213       ASSAULT              MAYHEM WITH A KNIFE    Sunday
#
#          Date   Time PdDistrict      Resolution                   Address  \
# 0  09/20/2015  23:54   RICHMOND       UNFOUNDED  3000 Block of CLEMENT ST
# 1  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 2  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 3  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 4  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
#
#             X          Y                               Location
# 0 -122.491851  37.781756  (37.7817557255921, -122.491851328976)
# 1 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 2 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 3 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 4 -122.413676  37.712617  (37.7126165766239, -122.413676487435)

# %%
crimedate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112331 entries, 0 to 112330
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IncidntNum  112331 non-null  int64
#  1   Category    112331 non-null  object
#  2   Descript    112331 non-null  object
#  3   DayOfWeek   112331 non-null  object
#  4   Date        112331 non-null  object
#  5   Time        112331 non-null  object
#  6   PdDistrict  112331 non-null  object
#  7   Resolution  112331 non-null  object
#  8   Address     112331 non-null  object
#  9   X           112331 non-null  float64
#  10  Y           112331 non-null  float64
#  11  Location    112331 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 10.3+ MB

# %% [markdown]
# Convert `Date` Column to DateTime and set as index

# %%
# ANSWER

crimedate['Date'] = pd.to_datetime(crimedate['Date'], format='%m/%d/%Y')
crimedate.set_index(keys=['Date'], inplace=True)

# %% [markdown]
# Draw a timeseries plot to visualize number of crimes for each day.

# %%
# ANSWER

crimedate.groupby(crimedate.index).size().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Using folium we can easily create a map. As it's SF data, by default we are using SF location.

# %%
def generateBaseMap(default_location=[37.76, -122.45], default_zoom_start=12):
    '''
    Create a base map
    '''
    base_map = folium.Map(
        location = default_location
        , control_scale = True
        , zoom_start = default_zoom_start
    )

    return base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9be88111b5298b5be3aae71b8088d676 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9be88111b5298b5be3aae71b8088d676&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9be88111b5298b5be3aae71b8088d676 = L.map(
#                 &quot;map_9be88111b5298b5be3aae71b8088d676&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9be88111b5298b5be3aae71b8088d676);
#
#
#
#
#
#             var tile_layer_0045ad6bfbadb660e2eb2d821b5ef961 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9be88111b5298b5be3aae71b8088d676);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a marker in the map using `Folium.Marker` for first 100 rows of the dataset.

# %%
# ANSWER
           
# 最初の100行のデータに対してマーカーを追加
for i in range(0, 100):  # 範囲を0から99に変更
    print([crimedate.iloc[i]['Y'], crimedate.iloc[i]['X'], crimedate.iloc[i]['Category']])  # 括弧を正しく閉じる
# Out:
# [37.7817557255921, -122.491851328976, 'NON-CRIMINAL']
# [37.7126165766239, -122.413676487435, 'ASSAULT']
# [37.7126165766239, -122.413676487435, 'ASSAULT']
# [37.7126165766239, -122.413676487435, 'ASSAULT']
# [37.7126165766239, -122.413676487435, 'ASSAULT']
# [37.7126165766239, -122.413676487435, 'OTHER OFFENSES']
# [37.7853339640306, -122.424688703591, 'OTHER OFFENSES']
# [37.7888040447734, -122.449684751771, 'VANDALISM']
# [37.7888040447734, -122.449684751771, 'DRUNKENNESS']
# [37.7211650807414, -122.437461502349, 'WARRANTS']
# [37.7746354223627, -122.444432207954, 'MISSING PERSON']
# [37.7746354223627, -122.444432207954, 'MISSING PERSON']
# [37.7749906792593, -122.410065781604, 'OTHER OFFENSES']
# [37.7744552453738, -122.430851581702, 'NON-CRIMINAL']
# [37.7535645746594, -122.395635436168, 'DRUG/NARCOTIC']
# [37.7535645746594, -122.395635436168, 'ASSAULT']
# [37.7535645746594, -122.395635436168, 'ASSAULT']
# [37.7882933915158, -122.408403859899, 'OTHER OFFENSES']
# [37.7568334631968, -122.408642782989, 'ROBBERY']
# [37.7464537868984, -122.419251697751, 'LARCENY/THEFT']
# [37.7395761096677, -122.41453967354, 'ASSAULT']
# [37.7669590343593, -122.416010580082, 'LARCENY/THEFT']
# [37.7669590343593, -122.416010580082, 'BURGLARY']
# [37.7752721501379, -122.41591119887, 'ROBBERY']
# [37.759419804663, -122.426036566526, 'NON-CRIMINAL']
# [37.8065526528708, -122.413789467437, 'LARCENY/THEFT']
# [37.728979731984, -122.385545453301, 'ASSAULT']
# [37.7629157386418, -122.421696153978, 'LARCENY/THEFT']
# [37.7780892579027, -122.44350785839, 'LARCENY/THEFT']
# [37.7763201416008, -122.482860593501, 'SECONDARY CODES']
# [37.7763201416008, -122.482860593501, 'RUNAWAY']
# [37.7763201416008, -122.482860593501, 'MISSING PERSON']
# [37.7804792523103, -122.473410842432, 'BURGLARY']
# [37.7738758568682, -122.42405956423, 'LARCENY/THEFT']
# [37.7373174011428, -122.390244392372, 'VEHICLE THEFT']
# [37.7373174011428, -122.390244392372, 'VEHICLE THEFT']
# [37.728979731984, -122.385545453301, 'SEX OFFENSES, FORCIBLE']
# [37.7351591086088, -122.421143845533, 'ASSAULT']
# [37.8013925469581, -122.432161214763, 'LARCENY/THEFT']
# [37.7602221178034, -122.432715763705, 'VEHICLE THEFT']
# [37.8025735991651, -122.40038746482, 'LARCENY/THEFT']
# [37.7279208527818, -122.383679778616, 'OTHER OFFENSES']
# [37.787245037815, -122.416642370005, 'LARCENY/THEFT']
# [37.7826335031541, -122.41487855905, 'VANDALISM']
# [37.7169389867046, -122.406669089962, 'VEHICLE THEFT']
# [37.7900934803531, -122.416386784625, 'OTHER OFFENSES']
# [37.7755926847208, -122.479106820552, 'VEHICLE THEFT']
# [37.7925182655105, -122.391004273278, 'LARCENY/THEFT']
# [37.8070362071183, -122.413814292432, 'VANDALISM']
# [37.7900934803531, -122.416386784625, 'LARCENY/THEFT']
# [37.7142802754796, -122.466196824742, 'VEHICLE THEFT']
# [37.7542509919387, -122.412619862692, 'SUSPICIOUS OCC']
# [37.7965510480789, -122.405283980519, 'NON-CRIMINAL']
# [37.7752488388293, -122.410287728099, 'SUSPICIOUS OCC']
# [37.7276340992506, -122.403595293514, 'SUSPICIOUS OCC']
# [37.7491100050973, -122.405096871916, 'NON-CRIMINAL']
# [37.7535645746594, -122.395635436168, 'VANDALISM']
# [37.7535645746594, -122.395635436168, 'BURGLARY']
# [37.7606220053743, -122.425842162189, 'VEHICLE THEFT']
# [37.7226578217429, -122.392612471936, 'WEAPON LAWS']
# [37.7226578217429, -122.392612471936, 'VANDALISM']
# [37.7687142722405, -122.453376250788, 'LARCENY/THEFT']
# [37.7991861177677, -122.419593646454, 'SUICIDE']
# [37.7991861177677, -122.419593646454, 'NON-CRIMINAL']
# [37.7544534411473, -122.403524795218, 'OTHER OFFENSES']
# [37.7367372564892, -122.424235953591, 'OTHER OFFENSES']
# [37.7803313209065, -122.406508487003, 'LARCENY/THEFT']
# [37.7355926105862, -122.390416955474, 'OTHER OFFENSES']
# [37.7186348402533, -122.441317001322, 'VEHICLE THEFT']
# [37.7650501214668, -122.419671780296, 'ASSAULT']
# [37.7543133191277, -122.41158898537, 'SUSPICIOUS OCC']
# [37.7849590112628, -122.419549568783, 'LARCENY/THEFT']
# [37.7769362014881, -122.416818891994, 'LARCENY/THEFT']
# [37.7685360123583, -122.41561633832, 'OTHER OFFENSES']
# [37.7685360123583, -122.41561633832, 'OTHER OFFENSES']
# [37.7764354063246, -122.415064887666, 'NON-CRIMINAL']
# [37.7717273141771, -122.441393701114, 'RUNAWAY']
# [37.7730330183515, -122.422127579529, 'NON-CRIMINAL']
# [37.7588312134679, -122.415781281593, 'DRUNKENNESS']
# [37.7122561827524, -122.417107986993, 'SUICIDE']
# [37.7122561827524, -122.417107986993, 'NON-CRIMINAL']
# [37.7247247919011, -122.430454305169, 'LARCENY/THEFT']
# [37.7218938677899, -122.410526271345, 'OTHER OFFENSES']
# [37.7815834072995, -122.423105855786, 'OTHER OFFENSES']
# [37.7963438994583, -122.400517100596, 'SUSPICIOUS OCC']
# [37.7650501214668, -122.419671780296, 'OTHER OFFENSES']
# [37.7859507767613, -122.40801449292, 'LARCENY/THEFT']
# [37.7686969786551, -122.453512911126, 'ASSAULT']
# [37.777647369969, -122.432423434485, 'LARCENY/THEFT']
# [37.7481554692332, -122.458680189782, 'NON-CRIMINAL']
# [37.7962022664393, -122.404766823685, 'LARCENY/THEFT']
# [37.80414615262, -122.425110613231, 'OTHER OFFENSES']
# [37.7529785864877, -122.405838144649, 'OTHER OFFENSES']
# [37.7529785864877, -122.405838144649, 'OTHER OFFENSES']
# [37.7529785864877, -122.405838144649, 'BURGLARY']
# [37.775675468707, -122.397538830416, 'ASSAULT']
# [37.7833104067015, -122.388379873919, 'LARCENY/THEFT']
# [37.7866151072472, -122.486211008775, 'LARCENY/THEFT']
# [37.7443223970163, -122.409517896115, 'LARCENY/THEFT']
# [37.7506650082311, -122.416953590297, 'OTHER OFFENSES']

# %% [markdown]
# Add a cricle in the map using `Folium Circle` for first 100 rows of the dataset.

# %%
# ANSWER

sf_location = [37.76, -122.45]
m = generateBaseMap(default_location=sf_location)

for i in range(0, len(crimedate.head(100))):
    folium.Marker(location=[crimedate.iloc[i]['Y'], crimedate.iloc[i]['X']], popup=crimedate.iloc[i]['Category']).add_to(m)

# %%
# ANSWER

sf_location = [37.76, -122.45]
m = generateBaseMap(default_location=sf_location)

for i in range(0, len(crimedate.head(100))):
    folium.Marker(location=[crimedate.iloc[i]['Y'], crimedate.iloc[i]['X']], popup=crimedate.iloc[i]['Category']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1aaa75fc512f3edff5b1e1da98cb3b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1aaa75fc512f3edff5b1e1da98cb3b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1aaa75fc512f3edff5b1e1da98cb3b7 = L.map(
#                 &quot;map_d1aaa75fc512f3edff5b1e1da98cb3b7&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#
#
#
#             var tile_layer_d4d622bad7a5ee1ca127448f5489598b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#             var marker_78741ba71cad45476430a7117091066e = L.marker(
#                 [37.7817557255921, -122.491851328976],
#                 {}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#         var popup_9814d0e1ba36bf86237302ab2fdb736b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4790ae71c49300fc6d9d7a8ece30dec = $(`&lt;div id=&quot;html_c4790ae71c49300fc6d9d7a8ece30dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_9814d0e1ba36bf86237302ab2fdb736b.setContent(html_c4790ae71c49300fc6d9d7a8ece30dec);
#
#
#
#         marker_78741ba71cad45476430a7117091066e.bindPopup(popup_9814d0e1ba36bf86237302ab2fdb736b)
#         ;
#
#
#
#
#             var marker_5bc52d550bcd04a6828791c27bbc9128 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#         var popup_cf06a9bc6f862ff1f5d889bd315e98a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d59be3e0b290b188d291054da67a726 = $(`&lt;div id=&quot;html_0d59be3e0b290b188d291054da67a726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_cf06a9bc6f862ff1f5d889bd315e98a2.setContent(html_0d59be3e0b290b188d291054da67a726);
#
#
#
#         marker_5bc52d550bcd04a6828791c27bbc9128.bindPopup(popup_cf06a9bc6f862ff1f5d889bd315e98a2)
#         ;
#
#
#
#
#             var marker_ab990d90c4c3b548944c33a2f36e7245 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#         var popup_46a42517640f9224c94d5f6cd5ca63ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca9bb2fbe58e0bb7403236faae27c2ae = $(`&lt;div id=&quot;html_ca9bb2fbe58e0bb7403236faae27c2ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_46a42517640f9224c94d5f6cd5ca63ed.setContent(html_ca9bb2fbe58e0bb7403236faae27c2ae);
#
#
#
#         marker_ab990d90c4c3b548944c33a2f36e7245.bindPopup(popup_46a42517640f9224c94d5f6cd5ca63ed)
#         ;
#
#
#
#
#             var marker_a984547e0bfbf94a79cbe1c9faf00d0d = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#         var popup_fb809f9fac265a88fb20d28c142d37c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aafbdc30f059dd8d3de387948f07784f = $(`&lt;div id=&quot;html_aafbdc30f059dd8d3de387948f07784f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_fb809f9fac265a88fb20d28c142d37c1.setContent(html_aafbdc30f059dd8d3de387948f07784f);
#
#
#
#         marker_a984547e0bfbf94a79cbe1c9faf00d0d.bindPopup(popup_fb809f9fac265a88fb20d28c142d37c1)
#         ;
#
#
#
#
#             var marker_54721cdb0ed8927a7fa509e5348bbf35 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_d1aaa75fc512f3edff5b1e1da98cb3b7);
#
#
#         var popup_d48fba848fec8a7263dbf8d0fef5a5c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2267440062f534bfbcb939d918cd68c8 = $(`&lt;div id=&quot;html_2267440062f534bfbcb939d918cd68c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_d48fba848fec8a7263dbf8d0fef5a5c5.setContent(html_2267440062f534bfbcb939d918cd68c8);
#
#
#
#         marker_54721cdb0ed8927a7fa509e5348bbf35.bindPopup(popup_d48fba848fec8a7263dbf8d0fef5a5c5)
#         ;

# %% [markdown]
# [BONUS] Create a heatmap of the incident happened in SF.

# %% [markdown]
# **HOMEWORK** Explore Folium as mush as you can.
#
# **HOMEWORK** Explore GeoPandas

# %% [markdown]
# # More Resources
#
# <a name="histfootnote">1</a>: [Histogram](https://en.wikipedia.org/wiki/Histogram)
#
# The matplotlib users' guide is at http://pageperso.lif.univ-mrs.fr/~francois.denis/IAAM1/Matplotlib.pdf.

# %% [markdown]
# For visualisation ideas and code see https://python-graph-gallery.com/:

# %% [markdown]
# 2: GeoPandas
#
# > The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.
#
# [GeoPandas 0.13.2](http://geopandas.org/index.html#)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
